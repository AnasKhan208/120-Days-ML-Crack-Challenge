# %%
print ("MD Shahriar Anas Khan")

# %%
x = 100
y = 200
x , y = y , x
print("x =", x ,"y =", y)

# %%
Cat = input("Input a number:")
print("You have entered:", Cat)
print("Type of the input is:", type(Cat))
Cat_float = float(Cat)
print("Type after conversion is:", type(Cat_float))

# %%
a = 100/3
print ( "value of A is : $",format(a, ".3f") )

# %%
second = input ("Enter seconds: ")
print (second)
Houres = int (second) // 3600
print (Houres)
remain_second = int (second) % 3600
print (remain_second)
Min = remain_second // 60
print (Min)
Sec = remain_second % 60
print (Houres, ":", Min, ":", Sec)
